# %%
from getpass import getpass
import os

user = getpass('BitBucket user')
password = getpass('BitBucket password')
os.environ['BITBUCKET_AUTH'] = user + ':' + password

# !git clone https://$BITBUCKET_AUTH@github.com/AshwinderK25/ChatBot
# Out:
# BitBucket user··········
# BitBucket password··········
# Cloning into 'ChatBot'...
# remote: Enumerating objects: 1485, done.
# remote: Counting objects: 100% (1485/1485), done.
# remote: Compressing objects: 100% (1273/1273), done.
# remote: Total 1485 (delta 189), reused 1431 (delta 170), pack-reused 0
# Receiving objects: 100% (1485/1485), 4.36 MiB | 19.59 MiB/s, done.
# Resolving deltas: 100% (189/189), done.

# %%
# %cd ChatBot/
# Out:
# /content/ChatBot

# %%
# %%writefile requirements.txt
# Flask==0.12.2
# flask-socketio
# eventlet==0.17.4
# gunicorn==18.0.0
# Out:
# Writing requirements.txt

# %%
import nltk
nltk.download('punkt')
nltk.download('stopwords')
nltk.download('wordnet')

# %%
get_ipython().system_raw(
    'pip3 install -r requirements.txt && python3 main.py > logs.txt 2>&1 &'
)

# %%
# !tail logs.txt
# Out:
#  * Restarting with stat
#  * Debugger is active!
#  * Debugger PIN: 302-686-744

# %%
pip install -r requirements.txt

# %%
PORT = 5000

# %%
# !curl http://localhost:5000/hello

# %%
# !wget https://bin.equinox.io/c/4VmDzA7iaHb/ngrok-stable-linux-amd64.zip
# !unzip ngrok-stable-linux-amd64.zip

# %%
get_ipython().system_raw('./ngrok http 5000 -host-header localhost:5000 &')

# !curl -s http://localhost:4040/api/tunnels | python3 -c \
    "import sys, json; print(json.load(sys.stdin)['tunnels'][0]['public_url'])"
# Out:
# http://3dfe402d.ngrok.io
